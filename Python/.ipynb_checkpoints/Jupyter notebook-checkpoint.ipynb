# %%
x = 3
y = 7
print(x + y)
print((x + y)*2)
# Out:
# 10
# 20

# %% [markdown]
# # hello world
# ## hello world
# ### hello world
#
# 1. hello world
# 2. hello world
# 3. hello world
#
#
# - hello world
# - hello world
# - hello world
#
#
# * hello world
# * hello world
#
#
# > hello world
#
#
# hello world *hello* world hello **world** hello world hello world
#
#
# | 구분 | 책 제목  | 판매량 | 가격 |
# |------|----------|--------|------|
# | 1    | 해리포터 | 100    | 1000 |
# | 2    | 헝거게임 | 200    | 2000 |

# %%
# %pwd
# Out:
# 'C:\\Users\\peter\\Documents\\Google 드라이브\\코딩 베이스캠프 실습\\Python'

# %%
# !pip3 install bs4
# Out:
# Requirement already satisfied: bs4 in c:\programdata\anaconda3\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\programdata\anaconda3\lib\site-packages (from bs4) (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in c:\programdata\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.2.1)

# %%
# %%time #실행시간 출력

print(sum(range(1, 1000000)))
# Out:
# 499999500000
# Wall time: 27.5 ms

# %%
# %%timeit #평균 실행 시간 출력

print(sum(range(1, 1000000)))
# Out:
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 499999500000
# 34.1 ms ± 1.01 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
def f(x, y):
    return x + y

# %%
f(3, 6)
# Out:
# 9

# %%
f? #가지고 있는 정보 확인

# %%
f?? #정보 확인 및 소스 코드 확인

# %%
# f + Shift + Tab : 툴팁형태로 도움말 생성

# %%
import random

random.randint(1, 10)
# Out:
# 5

# %% [markdown]
# ## 이미지를 업로드 합니다.
#
# ![temp.jpg](attachment:temp.jpg)

# %%
# %magic

# %%
l = [100, 200, 300]
#l. + Tab : 리스트 메서드 확인
# Out:
#   File "C:\Users\peter\AppData\Local\Temp/ipykernel_948/682693010.py", line 2
#     l. #l. + Tab : 리스트 메서드 확인
#        ^
# SyntaxError: invalid syntax

# %%
type(l)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_948/538381881.py in <module>
# ----> 1 type(l)
#
# NameError: name 'l' is not defined
